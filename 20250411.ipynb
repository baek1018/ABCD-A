# %% [markdown]
# <a href="https://colab.research.google.com/github/baek1018/ABCD-A/blob/20250411/20250411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i=0
result=0
while i<5:
  a=input("성적 입력:")
  result+=int(a)
  i+=1
  print(f'평균:{result/5}')
# Out:
# 성적 입력:10
# 평균:2.0
# 성적 입력:20
# 평균:6.0
# 성적 입력:10
# 평균:8.0
# 성적 입력:20
# 평균:12.0
# 성적 입력:15
# 평균:15.0

# %%
1=['Alice','Bob','Charlie']
for name in 1:
  print(name)
  else:
    print('!!FINISH!!')
    #Alice
    #Bob
    #charlie
    #!!FINISH!!

# %%
for name in 1:
  if name =='Bob':
    print('!!BREAK!!')
    break
    print(name)
    else:
      print('!!FINISH!!')
      #Alice
      #!!BREAK!!

# %%
for i in range(10,0,-3):
  print(i)
#10
#7
#4
#1

# %%
1=['Alice','Bob','Charlie']

for name in 1:
  print(name)
  #Alice
  #Bob
  #Charlie

  for i,name in enumerate(1):
    print(i,name)
    #0 Alice
    #1 Bob
    #2 Charlie

# %%
for i,name in enumerate(1,1):
  print(i,name)
#1 Alice
#2 Bob
#3 Charlie

for i,name in enumerate(1,42):
  print(i,name)
  #42 Alice
  #43 Bob
  #44 Charlie
