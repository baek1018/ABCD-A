# %% [markdown]
# <a href="https://colab.research.google.com/github/baek1018/ABCD-A/blob/20250307/20250311.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=100000
a='pig'
b='dad'
print(a)
print(b)
print(watch)
print(a+b)
print(a+' '+b)
# Out:
# pig
# dad
# 100000
# pigdad
# pig dad

# %%
aa=10
bb=2000
aa,bb=bb,aa
print(aa)
print(bb)
# Out:
# 2000
# 10

# %%
a1=[10,20,30]
b1=a1
a1[0]=200
print(b1)
# Out:
# [200, 20, 30]

# %%
#print 사용 예제입니다.
print("hello world")
print('hello world')
print(1)
print("1")
c=1
print("c="+str(c))
print("c=",c)
print("c={}",format(c))
# Out:
# hello world
# hello world
# 1
# 1
# c=1
# c= 1
# c={} 1

# %%
a=[10,20,30]
b=1
c=2
print(a)
print("a={}".format(a))
print("b={}".format(b))
print("a={},b={},c={}".format(a,b,c))
# Out:
# [10, 20, 30]
# a=[10, 20, 30]
# b=1
# a=[10, 20, 30],b=1,c=2
